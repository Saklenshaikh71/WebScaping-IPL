# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/saklenshaikh/Desktop/Masai/WebScraping /Project_2.0_IPL/IPL_ScapData.csv")
df
# Out:
#      Season_year Match_number  \
# 0    SEASON 2008     MATCH 59
# 1    SEASON 2008     MATCH 58
# 2    SEASON 2008     MATCH 57
# 3    SEASON 2008     MATCH 56
# 4    SEASON 2008     MATCH 55
# ..           ...          ...
# 939  SEASON 2023     MATCH 20
# 940  SEASON 2023     MATCH 19
# 941  SEASON 2023     MATCH 18
# 942  SEASON 2023     MATCH 17
# 943  SEASON 2023     MATCH 16
#
#                                                  Venue  \
# 0                        DY Patil Stadium, NAVI MUMBAI
# 1                             Wankhede Stadium, Mumbai
# 2                             Wankhede Stadium, Mumbai
# 3                            IS Bindra Stadium, Mohali
# 4                    M. Chinnaswamy Stadium, Bengaluru
# ..                                                 ...
# 939                   M Chinnaswamy Stadium, Bengaluru
# 940                              Eden Gardens, Kolkata
# 941  Punjab Cricket Association IS Bindra Stadium, ...
# ...

# %%
df['First team'] = df['First team'].str.replace('\n', ' ')

# Displaying the modified DataFrame
df
# Out:
#      Season_year Match_number  \
# 0    SEASON 2008     MATCH 59
# 1    SEASON 2008     MATCH 58
# 2    SEASON 2008     MATCH 57
# 3    SEASON 2008     MATCH 56
# 4    SEASON 2008     MATCH 55
# ..           ...          ...
# 939  SEASON 2023     MATCH 20
# 940  SEASON 2023     MATCH 19
# 941  SEASON 2023     MATCH 18
# 942  SEASON 2023     MATCH 17
# 943  SEASON 2023     MATCH 16
#
#                                                  Venue  \
# 0                        DY Patil Stadium, NAVI MUMBAI
# 1                             Wankhede Stadium, Mumbai
# 2                             Wankhede Stadium, Mumbai
# 3                            IS Bindra Stadium, Mohali
# 4                    M. Chinnaswamy Stadium, Bengaluru
# ..                                                 ...
# 939                   M Chinnaswamy Stadium, Bengaluru
# 940                              Eden Gardens, Kolkata
# 941  Punjab Cricket Association IS Bindra Stadium, ...
# ...

# %%
df['Second team'] = df['Second team'].str.replace('\n', ' ')

# Displaying the modified DataFrame
df
# Out:
#      Season_year Match_number  \
# 0    SEASON 2008     MATCH 59
# 1    SEASON 2008     MATCH 58
# 2    SEASON 2008     MATCH 57
# 3    SEASON 2008     MATCH 56
# 4    SEASON 2008     MATCH 55
# ..           ...          ...
# 939  SEASON 2023     MATCH 20
# 940  SEASON 2023     MATCH 19
# 941  SEASON 2023     MATCH 18
# 942  SEASON 2023     MATCH 17
# 943  SEASON 2023     MATCH 16
#
#                                                  Venue  \
# 0                        DY Patil Stadium, NAVI MUMBAI
# 1                             Wankhede Stadium, Mumbai
# 2                             Wankhede Stadium, Mumbai
# 3                            IS Bindra Stadium, Mohali
# 4                    M. Chinnaswamy Stadium, Bengaluru
# ..                                                 ...
# 939                   M Chinnaswamy Stadium, Bengaluru
# 940                              Eden Gardens, Kolkata
# 941  Punjab Cricket Association IS Bindra Stadium, ...
# ...

# %%
df
# Out:
#      Season_year Match_number  \
# 0    SEASON 2008     MATCH 59
# 1    SEASON 2008     MATCH 58
# 2    SEASON 2008     MATCH 57
# 3    SEASON 2008     MATCH 56
# 4    SEASON 2008     MATCH 55
# ..           ...          ...
# 939  SEASON 2023     MATCH 20
# 940  SEASON 2023     MATCH 19
# 941  SEASON 2023     MATCH 18
# 942  SEASON 2023     MATCH 17
# 943  SEASON 2023     MATCH 16
#
#                                                  Venue  \
# 0                        DY Patil Stadium, NAVI MUMBAI
# 1                             Wankhede Stadium, Mumbai
# 2                             Wankhede Stadium, Mumbai
# 3                            IS Bindra Stadium, Mohali
# 4                    M. Chinnaswamy Stadium, Bengaluru
# ..                                                 ...
# 939                   M Chinnaswamy Stadium, Bengaluru
# 940                              Eden Gardens, Kolkata
# 941  Punjab Cricket Association IS Bindra Stadium, ...
# ...

# %%
df.dtypes
# Out:
# Season_year     object
# Match_number    object
# Venue           object
# Date&Time       object
# winning team    object
# First team      object
# Second team     object
# link            object
# dtype: object

# %%
df.tail()
# Out:
#      Season_year Match_number  \
# 939  SEASON 2023     MATCH 20
# 940  SEASON 2023     MATCH 19
# 941  SEASON 2023     MATCH 18
# 942  SEASON 2023     MATCH 17
# 943  SEASON 2023     MATCH 16
#
#                                                  Venue  \
# 939                   M Chinnaswamy Stadium, Bengaluru
# 940                              Eden Gardens, Kolkata
# 941  Punjab Cricket Association IS Bindra Stadium, ...
# 942                    MA Chidambaram Stadium, Chennai
# 943                        Arun Jaitley Stadium, Delhi
#
#                      Date&Time                                winning team  \
# 939  APR, SAT 15 , 3:30 pm IST  ROYAL CHALLENGERS BANGALORE WON BY 23 RUNS
# 940  APR, FRI 14 , 7:30 pm IST          SUNRISERS HYDERABAD WON BY 23 RUNS
# 941  APR, THU 13 , 7:30 pm IST             GUJARAT TITANS WON BY 6 WICKETS
# 942  APR, WED 12 , 7:30 pm IST              RAJASTHAN ROYALS WON BY 3 RUNS
# ...

# %%
df[['Season_year','winning team']]
# Out:
#      Season_year                                winning team
# 0    SEASON 2008           RAJASTHAN ROYALS WON BY 3 WICKETS
# 1    SEASON 2008        CHENNAI SUPER KINGS WON BY 9 WICKETS
# 2    SEASON 2008            RAJASTHAN ROYALS WON BY 105 RUNS
# 3    SEASON 2008                 PUNJAB KINGS WON BY 41 RUNS
# 4    SEASON 2008             MUMBAI INDIANS WON BY 9 WICKETS
# ..           ...                                         ...
# 939  SEASON 2023  ROYAL CHALLENGERS BANGALORE WON BY 23 RUNS
# 940  SEASON 2023          SUNRISERS HYDERABAD WON BY 23 RUNS
# 941  SEASON 2023             GUJARAT TITANS WON BY 6 WICKETS
# 942  SEASON 2023              RAJASTHAN ROYALS WON BY 3 RUNS
# 943  SEASON 2023             MUMBAI INDIANS WON BY 6 WICKETS
#
# [944 rows x 2 columns]

# %%
df.describe()
# Out:
#         Season_year Match_number                     Venue  \
# count           944          944                       944
# unique           16           80                        43
# top     SEASON 2008     MATCH 59  Wankhede Stadium, Mumbai
# freq             59           16                        99
#
#                        Date&Time                     winning team  \
# count                        944                              944
# unique                       745                              453
# top     JUN, SUN 1 , 8:00 pm IST  MUMBAI INDIANS WON BY 5 WICKETS
# freq                           2                               18
#
#                           First team       Second team  \
# count                            944               944
# unique                           913               921
# top     MUMBAI INDIANS 187/5 (20 OV)  RAJASTHAN ROYALS
# freq                               3                 4
#
#                                            link
# ...

# %%
# Visualization 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# Heatmap 
#plt.figure(figsize = (1, 1))
#sns.heatmap(df.corr())

# %%
plt.bar(df['Season_year'], df['winning team'])
# Out:
# <BarContainer object of 944 artists>

# %%
df.dtypes
# Out:
# Season_year     object
# Match_number    object
# Venue           object
# Date&Time       object
# winning team    object
# First team      object
# Second team     object
# link            object
# dtype: object

# %%
plt.bar(df['Season_year'], df['Season_year'])
# Out:
# <BarContainer object of 944 artists>

# %%
# barplot 
#sns.barplot((df['Season_year'], df['Season_year']))

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Season_year', data=df)
plt.show()

# %%
# In 2013, we have the most number of matches

# %%
data = df['winning team'].value_counts()
data
# Out:
# winning team
# MUMBAI INDIANS WON BY 5 WICKETS               18
# PUNJAB KINGS WON BY 6 WICKETS                 18
# MUMBAI INDIANS WON BY 6 WICKETS               14
# KOLKATA KNIGHT RIDERS WON BY 7 WICKETS        12
# RAJASTHAN ROYALS WON BY 7 WICKETS             12
#                                               ..
# CHENNAI SUPER KINGS WON BY 15 RUNS             1
# MUMBAI INDIANS WON BY 60 RUNS                  1
# MUMBAI INDIANS WON BY 65 RUNS                  1
# KOLKATA KNIGHT RIDERS WON BY 46 RUNS           1
# ROYAL CHALLENGERS BANGALORE WON BY 23 RUNS     1
# Name: count, Length: 453, dtype: int64

# %%
plt.figure(figsize=(12,6))
#data = df.(winning team).value_counts()
sns.barplot(y = data.index, x = data, orient='h')
plt.show()

# %%
# Mumbai Indians are the winners in most of the matches

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Venue', data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [raw]
# # in the data with "Wankhade Mumbai" being the one with most number of matches followed by "M Chinnaswamy Stadium"

# %%
df.dtypes
# Out:
# Season_year     object
# Match_number    object
# Venue           object
# Date&Time       object
# winning team    object
# First team      object
# Second team     object
# link            object
# dtype: object

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='winning team', data=df)
plt.xticks(rotation=100)
plt.show()

# %% [raw]
# MI again leads the pack followed by CSK.

# %%
temp_df1 = df.drop_duplicates(subset=['Season_year'])[['Season_year', 'winning team']].reset_index(drop=True)
temp_df1
# Out:
#     Season_year                                       winning team
# 0   SEASON 2008                  RAJASTHAN ROYALS WON BY 3 WICKETS
# 1   SEASON 2009                      DECCAN CHARGERS WON BY 6 RUNS
# 2   SEASON 2010                 CHENNAI SUPER KINGS WON BY 22 RUNS
# 3   SEASON 2011                 CHENNAI SUPER KINGS WON BY 58 RUNS
# 4   SEASON 2012             KOLKATA KNIGHT RIDERS WON BY 5 WICKETS
# 5   SEASON 2013                      MUMBAI INDIANS WON BY 23 RUNS
# 6   SEASON 2014             KOLKATA KNIGHT RIDERS WON BY 3 WICKETS
# 7   SEASON 2015                      MUMBAI INDIANS WON BY 41 RUNS
# 8   SEASON 2016                  SUNRISERS HYDERABAD WON BY 8 RUNS
# 9   SEASON 2017                        MUMBAI INDIANS WON BY 1 RUN
# 10  SEASON 2018               CHENNAI SUPER KINGS WON BY 8 WICKETS
# 11  SEASON 2019                        MUMBAI INDIANS WON BY 1 RUN
# 12  SEASON 2020                    MUMBAI INDIANS WON BY 5 WICKETS
# ...

# %%
df.dtypes
# Out:
# Season_year     object
# Match_number    object
# Venue           object
# Date&Time       object
# winning team    object
# First team      object
# Second team     object
# link            object
# dtype: object

# %%
df.shape
# Out:
# (944, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 944 entries, 0 to 943
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Season_year   944 non-null    object
#  1   Match_number  944 non-null    object
#  2   Venue         944 non-null    object
#  3   Date&Time     944 non-null    object
#  4   winning team  944 non-null    object
#  5   First team    944 non-null    object
#  6   Second team   944 non-null    object
#  7   link          944 non-null    object
# dtypes: object(8)
# memory usage: 59.1+ KB

# %%
df.describe()
# Out:
#         Season_year Match_number                     Venue  \
# count           944          944                       944
# unique           16           80                        43
# top     SEASON 2008     MATCH 59  Wankhede Stadium, Mumbai
# freq             59           16                        99
#
#                        Date&Time                     winning team  \
# count                        944                              944
# unique                       745                              453
# top     JUN, SUN 1 , 8:00 pm IST  MUMBAI INDIANS WON BY 5 WICKETS
# freq                           2                               18
#
#                           First team       Second team  \
# count                            944               944
# unique                           913               921
# top     MUMBAI INDIANS 187/5 (20 OV)  RAJASTHAN ROYALS
# freq                               3                 4
#
#                                            link
# ...

# %%
df.Season_year.value_counts()
# Out:
# Season_year
# SEASON 2008    59
# SEASON 2009    59
# SEASON 2010    59
# SEASON 2011    59
# SEASON 2012    59
# SEASON 2013    59
# SEASON 2014    59
# SEASON 2015    59
# SEASON 2016    59
# SEASON 2017    59
# SEASON 2018    59
# SEASON 2019    59
# SEASON 2020    59
# SEASON 2021    59
# SEASON 2022    59
# SEASON 2023    59
# Name: count, dtype: int64

# %%
# The winning percentage of each teams:

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (16, 8)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
#new_column_names = {'A': 'Column1', 'B': 'Column2', 'C': 'Column3'}
#df.rename(columns=new_column_names, inplace=True)

# Updated DataFrame
#print("\nDataFrame with updated column names (original dataset modified):")
#print(df)

# %%
df['winner'] = df['winning team']
df['team1'] = df['First team']
df['team2'] = df['Second team']

# %%
df.dtypes
# Out:
# Season_year     object
# Match_number    object
# Venue           object
# Date&Time       object
# winning team    object
# First team      object
# Second team     object
# link            object
# winner          object
# team1           object
# team2           object
# dtype: object

# %%
win_percent=((df.winner.value_counts())/((df.team1.value_counts())+(df.team2.value_counts())))*100
winning_percent=win_percent.sort_values(ascending=False)
winning_percent
# Out:
# CHENNAI SUPER KINGS                                 NaN
# CHENNAI SUPER KINGS 107/4 (15.4 OV )                NaN
# CHENNAI SUPER KINGS 109 (17.4 OV)                   NaN
# CHENNAI SUPER KINGS 109 (19 OV )                    NaN
# CHENNAI SUPER KINGS 111/3 (17.2 OV)                 NaN
#                                                      ..
# SUNRISERS HYDERABAD WON BY 8 WICKETS (D/L METHOD)   NaN
# SUNRISERS HYDERABAD WON BY 85 RUNS                  NaN
# SUNRISERS HYDERABAD WON BY 88 RUNS                  NaN
# SUNRISERS HYDERABAD WON BY 9 RUNS                   NaN
# SUNRISERS HYDERABAD WON BY 9 WICKETS                NaN
# Name: count, Length: 2285, dtype: float64

# %%
df1['winning team']

# %%
df.dtypes

# %%
df['winner'].value_counts()
# Out:
# winner
# MUMBAI INDIANS WON BY 5 WICKETS               18
# PUNJAB KINGS WON BY 6 WICKETS                 18
# MUMBAI INDIANS WON BY 6 WICKETS               14
# KOLKATA KNIGHT RIDERS WON BY 7 WICKETS        12
# RAJASTHAN ROYALS WON BY 7 WICKETS             12
#                                               ..
# CHENNAI SUPER KINGS WON BY 15 RUNS             1
# MUMBAI INDIANS WON BY 60 RUNS                  1
# MUMBAI INDIANS WON BY 65 RUNS                  1
# KOLKATA KNIGHT RIDERS WON BY 46 RUNS           1
# ROYAL CHALLENGERS BANGALORE WON BY 23 RUNS     1
# Name: count, Length: 453, dtype: int64

# %%
ipl_match_played=(df.team1.value_counts()+df.team2.value_counts()).sort_values(ascending=False)
ipl_match_played
# Out:
# KOLKATA KNIGHT RIDERS                   4.0
# CHENNAI SUPER KINGS                     3.0
# CHENNAI SUPER KINGS 107/4 (15.4 OV )    NaN
# CHENNAI SUPER KINGS 109 (17.4 OV)       NaN
# CHENNAI SUPER KINGS 109 (19 OV )        NaN
#                                        ...
# SUNRISERS HYDERABAD 231/2 (20 OV)       NaN
# SUNRISERS HYDERABAD 44/2 (4.2 OV )      NaN
# SUNRISERS HYDERABAD 72/1 (8.0 OV )      NaN
# SUNRISERS HYDERABAD 81/4 (13.5 OV)      NaN
# SUNRISERS HYDERABAD 96 (17.4 OV)        NaN
# Name: count, Length: 1832, dtype: float64

# %%
top_10_venue=df.Venue.value_counts().head(10)
top_10_venue
# Out:
# Venue
# Wankhede Stadium, Mumbai                         99
# Eden Gardens, Kolkata                            81
# Arun Jaitley Stadium, Delhi                      81
# M. Chinnaswamy Stadium, Bengaluru                77
# Rajiv Gandhi Intl. Cricket Stadium, Hyderabad    58
# M. A. Chidambaram Stadium, Chennai               58
# IS Bindra Stadium, Mohali                        53
# Sawai Mansingh Stadium, Jaipur                   47
# Pune                                             34
# Dubai International Cricket Stadium, Dubai       33
# Name: count, dtype: int64

# %%
top_10_venue_df=pd.DataFrame({'Venue':top_10_venue.index,
                             'Count':top_10_venue.values})
top_10_venue_df
# Out:
#                                            Venue  Count
# 0                       Wankhede Stadium, Mumbai     99
# 1                          Eden Gardens, Kolkata     81
# 2                    Arun Jaitley Stadium, Delhi     81
# 3              M. Chinnaswamy Stadium, Bengaluru     77
# 4  Rajiv Gandhi Intl. Cricket Stadium, Hyderabad     58
# 5             M. A. Chidambaram Stadium, Chennai     58
# 6                      IS Bindra Stadium, Mohali     53
# 7                 Sawai Mansingh Stadium, Jaipur     47
# 8                                           Pune     34
# 9     Dubai International Cricket Stadium, Dubai     33

# %%
plt.title("Top 10 Venues of IPL Matches")

plt.pie(top_10_venue_df["Count"],labels=top_10_venue_df["Venue"])
# Out:
# ([<matplotlib.patches.Wedge at 0x14baa2ad0>,
# ...
#  [Text(0.9649008515342753, 0.5281726485803961, 'Wankhede Stadium, Mumbai'),
#   Text(0.17455075983859228, 1.086062628138806, 'Eden Gardens, Kolkata'),
#   Text(-0.6745934512494078, 0.8688634389427449, 'Arun Jaitley Stadium, Delhi'),
#   Text(-1.0931942497724845, 0.12217336970213646, 'M. Chinnaswamy Stadium, Bengaluru'),
#   Text(-0.9251052626127184, -0.5951304504780893, 'Rajiv Gandhi Intl. Cricket Stadium, Hyderabad'),
#   Text(-0.4407918280155045, -1.0078207004992257, 'M. A. Chidambaram Stadium, Chennai'),
#   Text(0.1635534497538694, -1.0877730779319779, 'IS Bindra Stadium, Mohali'),
#   Text(0.6701893143592692, -0.8722650302050706, 'Sawai Mansingh Stadium, Jaipur'),
#   Text(0.9622165560155217, -0.5330471830238188, 'Pune'),
#   Text(1.0847068098629051, -0.18278713476894165, 'Dubai International Cricket Stadium, Dubai')])

# %%
df.dtypes
# Out:
# Season_year     object
# Match_number    object
# Venue           object
# Date&Time       object
# winning team    object
# First team      object
# Second team     object
# link            object
# winner          object
# team1           object
# team2           object
# dtype: object
